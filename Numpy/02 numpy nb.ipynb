# %% [markdown]
# # Demo numpy (ipynb)

# %%
# %pip install numpy
# %pip install matplotlib
# Out:
# Requirement already satisfied: numpy in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.1)
# Requirement already satisfied: six>=1.5 in /Users/bart/Documents/Les/Les_OpenCV_Demo_2026/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## imports

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## code

# %%
mijn_Afbeelding = np.zeros((18, 18), dtype=np.uint8)
plt.imshow(mijn_Afbeelding, cmap='gray')
